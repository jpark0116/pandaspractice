# %%
import pandas as pd

# %%
df = pd.read_csv('/private/var/mobile/Containers/Data/Application/75B952C2-8D4C-4F28-8D25-F02982BE16C8/Documents/survey_results_public.csv',
                index_col = 'Respondent')
schema_df = pd.read_csv('/private/var/mobile/Containers/Data/Application/75B952C2-8D4C-4F28-8D25-F02982BE16C8/Documents/survey_results_schema.csv',
                index_col = 'Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_colwidth', None)

# %%
high_salary = (df['ConvertedComp'] > 70000 )

# %%
df.loc[high_salary,
       ['Country','LanguageWorkedWith','ConvertedComp']
      ]
# Out:
#                    Country  \
# Respondent
# 6                   Canada
# 9              New Zealand
# 13           United States
# 16          United Kingdom
# 22           United States
# ...                    ...
# 88876        United States
# 88877        United States
# 88878        United States
# 88879              Finland
# 88882          Netherlands
#
#                                                                                             LanguageWorkedWith  \
# Respondent
# 6                                                                                                   Java;R;SQL
# 9           Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;Python;Ruby;Rust;SQL;TypeScript;WebAssembly;Other(s):
# 13                                                Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 16                                                 Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;TypeScript;VBA
# ...

# %%
countries = ['United States', 
             'India',
             'United Kingdom',
             'Germany'
             'Canada'
            ]
filt = df['Country'].isin(countries)

# %%
df.loc[filt,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 8                 India
# 10                India
# 13        United States
#               ...
# 84539    United Kingdom
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# Name: Country, Length: 35747, dtype: object

# %%
filt1 = df['LanguageWorkedWith'].str.contains('Python', na = False)

# %%
df.loc[filt1, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                                        HTML/CSS;Java;JavaScript;Python
# 2                                                    C++;HTML/CSS;Python
# 4                                                    C;C++;C#;Python;SQL
# 5                            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;JavaScript;Python;SQL
#                                       ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;JavaScript;Python;SQL
# 85738                    Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566                    Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739                           C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                                         HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object
